# %% [markdown]
# <a href="https://colab.research.google.com/github/humayraR/LeetspeakMining/blob/main/Accuracy_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Accuracy test analysis

# %%
result_df = pd.read_csv("pyleet_accuracy_result.csv")
result_df
# Out:
#                  word      pyleetspeak            minedLeet      BestMatches  \
# 0              edards           3dards           ['3dards']           awards
# 1               lrapa            lr@p@            ['lr@p@']            lrApA
# 2             marburg          m@rb_rg          ['m@rb_rg']          mArbArg
# 3              tigate           tigat3           ['tigat3']           tights
# 4           originals        0r1g1n4ls        ['0r1g1n4ls']        OrIgInAls
# ...               ...              ...                  ...              ...
# 4995        indierock        1nd13rock        ['1nd13rock']        IndIErock
# 4996          rpgamer          rpg@m3r          ['rpg@m3r']          rpgAmEr
# 4997  anaesthesiology  4n43sth3s10l0gy  ['4n43sth3s10l0gy']  AnAEsthEsIOlOgy
# 4998         dietikon         di3tik0n         ['di3tik0n']         diEtikOn
# 4999      spitzbergen      sp1tzb3rg3n      ['sp1tzb3rg3n']      spItzbErgEn
#
#      correct
# 0         no
# 1        yes
# ...

# %%
yes = result_df[result_df['correct'] =='yes']
#no - try to match words that are already in the dictionary, if can't match, do direct substitution, mostly words  that resemble(close to) some words but not in dictionary
#none - word lengths>=15
yes
# Out:
#                  word      pyleetspeak            minedLeet      BestMatches  \
# 1               lrapa            lr@p@            ['lr@p@']            lrApA
# 4           originals        0r1g1n4ls        ['0r1g1n4ls']        OrIgInAls
# 5         aggravating      @ggr4vat1ng      ['@ggr4vat1ng']      AggrAvatIng
# 6        gamessiemens     g@m3ss13mens     ['g@m3ss13mens']     gAmEssIEmens
# 7        luedenscheid     luedensche1d     ['luedensche1d']     luedenscheId
# ...               ...              ...                  ...              ...
# 4995        indierock        1nd13rock        ['1nd13rock']        IndIErock
# 4996          rpgamer          rpg@m3r          ['rpg@m3r']          rpgAmEr
# 4997  anaesthesiology  4n43sth3s10l0gy  ['4n43sth3s10l0gy']  AnAEsthEsIOlOgy
# 4998         dietikon         di3tik0n         ['di3tik0n']         diEtikOn
# 4999      spitzbergen      sp1tzb3rg3n      ['sp1tzb3rg3n']      spItzbErgEn
#
#      correct
# 1        yes
# 4        yes
# ...

# %%
no = result_df[result_df['correct'] =='no']
no
# Out:
#              word  pyleetspeak        minedLeet  BestMatches correct
# 0          edards       3dards       ['3dards']       awards      no
# 2         marburg      m@rb_rg      ['m@rb_rg']      mArbArg      no
# 3          tigate       tigat3       ['tigat3']       tights      no
# 10    leaguerugby  l3@g_3r_gby  ['l3@g_3r_gby']  lEAgAErAgby      no
# 11          pazzo        p4zz0        ['p4zz0']        pIzzA      no
# ...           ...          ...              ...          ...     ...
# 4978        stang        st4ng        ['st4ng']        stIng      no
# 4989       mascom       m@scom       ['m@scom']       mascot      no
# 4992         cies         c13s         ['c13s']         lies      no
# 4993        aijaz        a1jaz        ['a1jaz']         ajar      no
# 4994        dring        dr1ng        ['dr1ng']        doing      no
#
# [1622 rows x 5 columns]

# %%
# prompt: Using dataframe result_df: find rows with result_df['correct'] = None

null = result_df[result_df['correct'].isnull()]
null
# Out:
#                     word         pyleetspeak minedLeet BestMatches correct
# 19    westvirginiamentor  w3stv1rg1ni4m3ntor        []         NaN     NaN
# 20                  nnnn                nnnn        []         NaN     NaN
# 30                chksum              chksum        []         NaN     NaN
# 45            candystand          candystand        []         NaN     NaN
# 54             enfeebled           enfeebled        []         NaN     NaN
# ...                  ...                 ...       ...         ...     ...
# 4924              brandx              brandx        []         NaN     NaN
# 4936             phycore             phycore        []         NaN     NaN
# 4977                 jmm                 jmm        []         NaN     NaN
# 4981              shrtwv              shrtwv        []         NaN     NaN
# 4990           swindling           swindling        []         NaN     NaN
#
# [562 rows x 5 columns]

# %%
# prompt: Using dataframe result_df: replace all None values with "None" string

result_df = result_df.fillna('None')

# %%
result_df
# Out:
#                  word      pyleetspeak            minedLeet      BestMatches  \
# 0              edards           3dards           ['3dards']           awards
# 1               lrapa            lr@p@            ['lr@p@']            lrApA
# 2             marburg          m@rb_rg          ['m@rb_rg']          mArbArg
# 3              tigate           tigat3           ['tigat3']           tights
# 4           originals        0r1g1n4ls        ['0r1g1n4ls']        OrIgInAls
# ...               ...              ...                  ...              ...
# 4995        indierock        1nd13rock        ['1nd13rock']        IndIErock
# 4996          rpgamer          rpg@m3r          ['rpg@m3r']          rpgAmEr
# 4997  anaesthesiology  4n43sth3s10l0gy  ['4n43sth3s10l0gy']  AnAEsthEsIOlOgy
# 4998         dietikon         di3tik0n         ['di3tik0n']         diEtikOn
# 4999      spitzbergen      sp1tzb3rg3n      ['sp1tzb3rg3n']      spItzbErgEn
#
#      correct
# 0         no
# 1        yes
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
result_df.groupby('correct').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.xlabel('Word count')
plt.ylabel('Correctness of spelling')
# Out:
# Text(0, 0.5, 'Correctness of spelling')

# %%
# prompt: Using dataframe result_df: suggest plots

result_df.groupby('correct').size().plot(kind='bar')
# Out:
# <Axes: xlabel='correct'>

# %%
result_df

# %%
yes.to_csv('yes.csv', index = False)
no.to_csv('no.csv', index = False)
null.to_csv('null.csv', index = False)

# %% [markdown]
# # Profanity Test analysis

# %%
profanity_df = pd.read_csv("profanity_test_result.csv")
profanity_df
# Out:
#       Unnamed: 0             text canonical_form_1 canonical_form_2  \
# 0              0               69               69              NaN
# 1              1              @55              ass              NaN
# 2              2         @ssfcker             fuck              ass
# 3              3        @ssfucker             fuck              ass
# 4              4        @ssfvcker             fuck              ass
# ...          ...              ...              ...              ...
# 1593        1593            wnker             wank              NaN
# 1594        1594              wop              wop              NaN
# 1595        1595          wophead              wop              NaN
# 1596        1596  zip in the wire       zipperhead              NaN
# 1597        1597       zipperhead       zipperhead              NaN
#
#      canonical_form_3      minedLeet    BestMatches  correct
# 0                 NaN             []             []       []
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
profanity_df.groupby('correct').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.xlabel('Word count')
plt.ylabel('Correctness of spelling')
# Out:
# Text(0, 0.5, 'Correctness of spelling')

# %%
# prompt: Using dataframe profanity_df: drop unnamed column

profanity_df.drop(columns='Unnamed: 0', axis=1, inplace=True)

# %%
profanity_df
# Out:
#                  text canonical_form_1 canonical_form_2 canonical_form_3  \
# 0                  69               69              NaN              NaN
# 1                 @55              ass              NaN              NaN
# 2            @ssfcker             fuck              ass              NaN
# 3           @ssfucker             fuck              ass              NaN
# 4           @ssfvcker             fuck              ass              NaN
# ...               ...              ...              ...              ...
# 1593            wnker             wank              NaN              NaN
# 1594              wop              wop              NaN              NaN
# 1595          wophead              wop              NaN              NaN
# 1596  zip in the wire       zipperhead              NaN              NaN
# 1597       zipperhead       zipperhead              NaN              NaN
#
#           minedLeet    BestMatches  correct
# 0                []             []       []
# ...

# %%
# prompt: Using dataframe profanity_df: get rows with profanity_df['correct'] containing 'yes'

profanity_yes = profanity_df[profanity_df.correct.str.contains('yes')]
profanity_no = profanity_df[profanity_df.correct.str.contains('no')]
profanity_yes
# Out:
#                text canonical_form_1 canonical_form_2 canonical_form_3  \
# 2          @ssfcker             fuck              ass              NaN
# 3         @ssfucker             fuck              ass              NaN
# 4         @ssfvcker             fuck              ass              NaN
# 5           @sshole              ass              NaN              NaN
# 8            0rg@sm           orgasm              NaN              NaN
# ...             ...              ...              ...              ...
# 1574        we1back          wetback              NaN              NaN
# 1580          wh0r3            whore              NaN              NaN
# 1581          wh0re            whore              NaN              NaN
# 1586          whor3            whore              NaN              NaN
# 1590  willy-whacker    willy-whacker              NaN              NaN
#
#               minedLeet        BestMatches  correct
# 2          ['@ssfcker']       ['Assfcker']  ['yes']
# ...

# %%
profanity_no
# Out:
#              text canonical_form_1 canonical_form_2 canonical_form_3  \
# 6       0ral seks              sex              NaN              NaN
# 7        0ral sex              sex              NaN              NaN
# 10    3jakulating      ejaculation              NaN              NaN
# 13          4r5es             arse              NaN              NaN
# 14          4skin         foreskin              NaN              NaN
# ...           ...              ...              ...              ...
# 1339     she-male          shemale              NaN              NaN
# 1349        shi+y             shit              NaN              NaN
# 1443   sixty-nine               69              NaN              NaN
# 1444       sk@nks            skank              NaN              NaN
# 1451     sl@nteye        slant eye              NaN              NaN
#
#             minedLeet      BestMatches correct
# 6            ['0ral']         ['Oral']  ['no']
# ...

# %%
# prompt: Using dataframe profanity_df: get rows with profanity_df['correct'] containing no 'yes' and no 'no'

profanity_null = profanity_df[~profanity_df['correct'].str.contains('yes|no')]
profanity_null
# Out:
#                  text canonical_form_1 canonical_form_2 canonical_form_3  \
# 0                  69               69              NaN              NaN
# 1                 @55              ass              NaN              NaN
# 19              abbie          abraham              NaN              NaN
# 20              abeed            abeed              NaN              NaN
# 21               aboe              abo              NaN              NaN
# ...               ...              ...              ...              ...
# 1593            wnker             wank              NaN              NaN
# 1594              wop              wop              NaN              NaN
# 1595          wophead              wop              NaN              NaN
# 1596  zip in the wire       zipperhead              NaN              NaN
# 1597       zipperhead       zipperhead              NaN              NaN
#
#      minedLeet BestMatches correct
# 0           []          []      []
# ...

# %%
profanity_yes.to_csv('profanity_yes.csv', index = False)
profanity_no.to_csv('profanity_no.csv', index = False)
profanity_null.to_csv('profanity_null.csv', index = False)
