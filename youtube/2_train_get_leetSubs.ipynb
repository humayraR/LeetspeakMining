# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax
from tqdm import tqdm, trange

# %%
train = pd.read_csv("train_yt.csv")
train = train.sample(frac = 0.75) # limiting train size due to time limit 
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 80290 entries, 47884 to 98114
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    80290 non-null  object
# dtypes: object(1)
# memory usage: 1.2+ MB

# %%
#load existing leet dictionary to initiate
import json
leet_fp = {}
with open('../accuracy/pyleetspeak_leetDict.json') as json_file:
    leet_fp = json.load(json_file)

leet_fp
# Out:
# {'A': {'0': 372, '3': 402, '4': 266, '@': 284, '_': 278, '1': 348},
#  'B': {'0': 40, '4': 20, '3': 38, '1': 36, '_': 40, '@': 20},
#  'C': {'3': 35, '@': 26, '4': 12, '_': 24, '1': 29, '0': 38},
#  'D': {'0': 46, '3': 47, '4': 33, '@': 33, '_': 51, '1': 34},
#  'E': {'3': 514, '0': 299, '1': 245, '_': 216, '@': 145, '4': 158},
#  'F': {'0': 29, '@': 23, '_': 27, '1': 21, '3': 23, '4': 13},
#  'G': {'3': 53, '_': 41, '0': 45, '1': 39, '@': 30, '4': 18},
#  'H': {'3': 34, '0': 44, '@': 24, '_': 28, '4': 23, '1': 29},
#  'I': {'1': 358, '0': 254, '@': 120, '3': 246, '4': 107, '_': 190},
#  'J': {'3': 11, '_': 10, '1': 8, '@': 7, '4': 3, '0': 9},
#  'K': {'0': 26, '3': 23, '@': 22, '_': 18, '4': 11, '1': 31},
#  'L': {'0': 69, '3': 61, '@': 44, '_': 38, '1': 53, '4': 29},
#  'M': {'4': 31, '3': 41, '@': 33, '_': 45, '1': 41, '0': 48},
#  'N': {'0': 74, '3': 83, '@': 37, '4': 42, '_': 61, '1': 57},
#  'O': {'0': 397, '3': 289, '@': 134, '1': 265, '4': 146, '_': 211},
#  'P': {'4': 30, '3': 36, '_': 38, '1': 33, '@': 48, '0': 41},
#  'Q': {'_': 3, '4': 1, '0': 1, '3': 1},
#  'R': {'0': 66, '1': 64, '3': 88, '@': 28, '4': 32, '_': 54},
#  'S': {'0': 99, '3': 92, '4': 66, '@': 56, '_': 61, '1': 88, '5': 1},
#  'T': {'0': 75, '3': 77, '@': 53, '4': 52, '_': 65, '1': 62, '+': 1, '7': 1},
#  'U': {'_': 163, '0': 175, '@': 65, '3': 163, '1': 149, '4': 74},
#  'V': {'3': 11, '_': 19, '4': 5, '1': 17, '@': 9, '0': 21},
#  'W': {'3': 28, '4': 15, '_': 20, '@': 23, '1': 19, '0': 28},
#  'X': {'3': 6, '4': 4, '_': 9, '@': 4, '1': 6, '0': 5},
#  'Y': {'3': 61, '_': 46, '4': 38, '0': 49, '@': 35, '1': 49},
#  'Z': {'@': 7, '4': 6, '3': 7, '_': 15, '1': 5, '0': 7}}

# %%
import LeetMining as lm
lm.setupLeetDict()
lm.initiateLeetDict(leet_dict=leet_fp)

# %% [markdown]
# # LeetSpeak processing

# %%
# Run leet algorithm on train data to extract leet words and their substitutions
trainLeet = {'text':[], 'leetWords':[], 'candidates':[]}

for i in trange(len(train['text'].values)):
    trainLeet['text'].append(train['text'].values[i])

    leetWords = lm.getLeetWordList(train['text'].values[i])
    trainLeet['leetWords'].append(leetWords)
    candidates = []
    for lword in leetWords:
        possibleMatches = lm.getMatchList(lword)
        candidates.append(possibleMatches)
        possibleSubs = lm.getPossibleSubstitutions(lword, possibleMatches)
        lm.updateLeetDict(possibleSubs)
    trainLeet['candidates'].append(candidates)

train1_result_df = pd.DataFrame(trainLeet)
train1_result_df.head()
# Out:
# 100%|██████████| 80290/80290 [2:52:39<00:00,  7.75it/s]
#                                                 text leetWords candidates
# 0  Never gonna give you up!! Specially made for y...        []         []
# 1  but I'm waiting on my 2060, does that mean not...        []         []
# 2  After 3 months they get a pension, what a life...        []         []
# 3                                               Yes.        []         []
# 4  What trump had a yt channel?! Would have never...        []         []

# %%
# print rows with leetspeak
train1_result_df[train1_result_df['leetWords'].str.len() >0] #just the rows with leetspeak
# Out:
#                                                     text  \
# 7      In Yuma, Arizona, USA they used to use a batht...
# 9      "<a href=""https://www.youtube.com/watch?v=0Sz...
# 18                                                  18th
# 19     Tom: I'm about twice your age and don't hear m...
# 22     Estimated waiting time:<br>4m 37s<br>4m 36s<br...
# ...                                                  ...
# 80272  "@<a href=""https://www.youtube.com/watch?v=pK...
# 80284  "<a href=""https://www.youtube.com/watch?v=98H...
# 80285  James: Update your iphones!<br><br>Me on jail ...
# 80287  27 years ago I paid $250 to get a massive 40MB...
# 80289  Thank god for 2x speed,(reply>), @Rodney K rea...
#
#                                                leetWords  \
# 7                                            [(saw, up)]
# 9                             [com/watch, v=0Sz55gmNUaI]
# 18                                                [18th]
# 19                                         [Tom:, 10KHz]
# 22     [time:, 4m, 37s, 4m, 36s, 4m, 35s, 4m, 32s, 4m...
# ...                                                  ...
# 80272                         [com/watch, v=pKkFaeig1zo]
# 80284                         [com/watch, v=98HZanvAJ8Y]
# 80285                                           [James:]
# 80287                                       [40MB, 40MB]
# 80289                                               [2x]
#
#                                               candidates
# 7                           [[saw], [upa, ups, upp, up]]
# 9                                               [[], []]
# 18     [[rath, moth, seth, path, myth, lith, ith, cat...
# 19                   [[tomo, tome, tomb, tom, toms], []]
# 22     [[timed, times, time, timer], [om, um, em, am,...
# ...                                                  ...
# 80272                                           [[], []]
# 80284                                           [[], []]
# 80285                                          [[james]]
# 80287  [[comb, lamb, limb, dumb, jamb, womb, bomb, to...
# 80289                                 [[ax, ix, ex, ox]]
#
# [16098 rows x 3 columns]

# %%
#go through the result df to see what causes challenges in detecting leetspeak? -> measurement units with numbers, href, etc
, '«': 6, '☐': 9, '《': 1}, 'F': {'0': 320, '@': 24, '_': 35, '1': 580, '3': 275, '4': 200, '7': 185, '6': 102, '5': 162, '2': 573, ':': 204, '(': 361, ';': 748, '9': 200, '*': 88, '8': 127, '-': 91, '+': 55, '/': 96, '[': 10, '%': 2, '`': 5, '$': 97, ')': 76, '„': 3, '=': 2, '^': 1, '~': 4, '，': 1, ']': 8, '\xa0': 10, '\\': 32, '€': 1, '˹': 2, '―': 1, '#': 2, '£': 1, '«': 7, '—': 1, '☐': 8, '《': 1}, 'G': {'3': 391, '_': 54, '0': 158, '1': 665, '@': 34, '4': 293, '5': 217, ':': 450, '8': 274, '(': 351, '7': 195, ';': 761, '9': 612, '6': 107, '*': 63, '+': 101, '[': 9, '2': 558, ')': 130, '`': 2, '$': 83, '/': 160, '-': 83, '„': 3, '=': 1, '~': 15, ']': 7, '\xa0': 7, '%': 1, '\\': 28, '˹': 3, '£': 3, '#': 1, '«': 4, '^': 2, '€': 1, '☐': 5, '《': 1}, 'H': {'3': 377, '0': 363, '@': 24, '_': 41, '4': 351, '1': 768, '5': 259, ':': 579, ';': 1022, '(': 457, '7': 193, '/': 140, '9': 651, '6': 119, '8': 307, '+': 112, '[': 9, '2': 587, '%': 4, '`': 5, ')': 205, '-': 131, '*': 91, '#': 7, '´': 4, '$': 69, '„': 3, '=': 1, '~': 8, '\xa0': 24, ']': 18, '，': 1, '\\': 36, '˹': 4, '―': 3, '¹': 5, '«': 4, '^': 4, '☐': 4, '《': 1}, 'I': {'1': 1962, '0': 4836, '@': 133, '3': 1118, '4': 1017, '_': 215, '8': 996, '7': 548, '6': 425, '5': 1070, '2': 1427, ':': 1316, ';': 2014, '(': 248, '´': 9, '9': 1611, '^': 24, '*': 211, ')': 290, '-': 783, '+': 305, '/': 599, '[': 8, '%': 14, '~': 19, '=': 40, '$': 168, '#': 33, '°': 21, '!': 14, '²': 1, '`': 5, '„': 3, ']': 9, '\xa0': 23, '|': 2, '¡': 1, '—': 1, '\\': 17, '€': 19, '˹': 1, '―': 1, '£': 6, '¹': 11, '«': 9, '☐': 9, '《': 1}, 'J': {'3': 147, '_': 10, '1': 412, '@': 7, '4': 119, '0': 26, '5': 64, ':': 99, '(': 203, '7': 76, '9': 140, '6': 71, '2': 306, '8': 102, '/': 58, '[': 9, '$': 50, '*': 46, ')': 35, '„': 3, ';': 17, '=': 1, '-': 14, '~': 2, '+': 4, ']': 8, '\xa0': 5, '\\': 18, '˹': 1, '«': 2, '☐': 2, '《': 1}, 'K': {'0': 322, '3': 237, '@': 23, '_': 29, '4': 223, '1': 462, '7': 166, '6': 76, '5': 183, '2':  ...

# %%
#collect training results - leet dict and the result table
import json
with open("youtube_leetDict.json", "w") as outfile: 
    json.dump(lm.getLeetDict(), outfile)
