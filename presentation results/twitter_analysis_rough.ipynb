# %% [markdown]
# <a href="https://colab.research.google.com/github/humayraR/LeetspeakMining/blob/main/twitter_analysis_rough.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# # Accuracy test analysis

# %%
result1_df = pd.read_csv("test1_result.csv")
result1_df
# Out:
#          keyword                                              reply       Neg  \
# 0       Dogecoin                 Hodling like there is no tomorrow!  0.061756
# 1        Vaccine                    As they tell us to not worry. 👀  0.078209
# 2      World Cup                                        I love this  0.009743
# 3       COVID-19  I hope so, but i have no need of immediate inf...  0.015798
# 4       COVID-19  Nuremberg doctors' trial was an important mile...  0.005117
# ...          ...                                                ...       ...
# 51072    Bitcoin                             Entropy, what is that?  0.347224
# 51073    Bitcoin               Reach out to the good guys at  &amp;  0.013548
# 51074    weather                     You should see Marquette, MI 😳  0.036081
# 51075      Tesla  You mean promoting peace and confronting corru...  0.820573
# 51076        NFT         This is so fucking bullish holy shit $PSTH  0.006388
#
#             Neu       Pos
# ...

# %%
result2_df = pd.read_csv("test2_result_trial2.csv")
result2_df
# Out:
#          keyword                                              reply  \
# 0       Dogecoin                 Hodling like there is no tomorrow!
# 1        Vaccine                    As they tell us to not worry. 👀
# 2      World Cup                                        I love this
# 3       COVID-19  I hope so, but i have no need of immediate inf...
# 4       COVID-19  Nuremberg doctors' trial was an important mile...
# ...          ...                                                ...
# 51072    Bitcoin                             Entropy, what is that?
# 51073    Bitcoin               Reach out to the good guys at  &amp;
# 51074    weather                     You should see Marquette, MI 😳
# 51075      Tesla  You mean promoting peace and confronting corru...
# 51076        NFT         This is so fucking bullish holy shit $PSTH
#
#                  leetWords BestMatches  \
# 0                       []          []
# 1                       []          []
# ...

# %%
#compare sentiment distributios for both tests
result1_df['Neu'].plot(kind='hist', bins=20, title='Neu')
result2_df['Neu'].plot(kind='hist', bins=20, title='Neu')
# result1_df['Neg'].plot(kind='hist', bins=20, title='Neg')
# result2_df['Neg'].plot(kind='hist', bins=20, title='Neg')
# result1_df['Pos'].plot(kind='hist', bins=20, title='Pos')
# result2_df['Pos'].plot(kind='hist', bins=20, title='Pos')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
plt.hist(result1_df['Neu'],
         alpha=0.5, # the transaparency parameter
         label='Neu1',
         color="blue",edgecolor='black', linewidth=1.2)

plt.hist(result2_df['Neu'],
         alpha=0.2,
         label='Neu2',
         color="orange",edgecolor='black', linewidth=1.2)

plt.legend(loc='upper right')
plt.title('Overlapping with both alpha=0.5')
plt.show()

# %%
avg_compare = {
    "Sentiments" : ['Pos', 'Neg', 'Neu'],
    "Before_leet_translate": [result1_df['Pos'].mean(), result1_df['Neu'].mean(), result1_df['Neg'].mean()],
    "After_leet_translate": [result2_df['Pos'].mean(), result2_df['Neu'].mean(), result2_df['Neg'].mean()],
}
avg_compare_df = pd.DataFrame(avg_compare)
avg_compare_df
# Out:
#   Sentiments  Before_leet_translate  After_leet_translate
# 0        Pos               0.281593              0.279099
# 1        Neg               0.365190              0.365648
# 2        Neu               0.353216              0.355253

# %%
meanPos = pd.DataFrame(avg_compare)
meanPos.index = meanPos["Sentiments"]
plt.figure().set_figwidth(15)
plt.figure().set_figheight(50)
meanPos.plot.bar(title="Positive Sentiment Analysis by keywords")
plt.ylabel("Sentiment Score")

plt.show()

# %%
# prompt: Using dataframe result1_df: suggest plots

# plot the distribution of negative sentiment scores
result1_df['Neg'].plot.hist()

# plot the distribution of neutral sentiment scores
result1_df['Neu'].plot.hist()

# plot the distribution of positive sentiment scores
result1_df['Pos'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# prompt: Using dataframe result1_df: bar plot mean of neg Neu and Pos

result1_df.groupby(['keyword'])[['Neg', 'Neu', 'Pos']].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='keyword'>

# %%
# prompt: Using dataframe result1_df: suggest plots

# plot the distribution of negative sentiment scores
result2_df['Neg'].plot.hist()

# plot the distribution of neutral sentiment scores
result2_df['Neu'].plot.hist()

# plot the distribution of positive sentiment scores
result2_df['Pos'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# prompt: Using dataframe result2_df: suggest plot

result2_df.groupby('keyword').mean().plot(kind='bar')
# Out:
# <ipython-input-91-f5564fe6faf0>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   result2_df.groupby('keyword').mean().plot(kind='bar')
# <Axes: xlabel='keyword'>

# %%
result1_df.groupby('keyword').mean().plot(kind='bar')
# Out:
# <ipython-input-94-9184d574b710>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   result1_df.groupby('keyword').mean().plot(kind='bar')
# <Axes: xlabel='keyword'>

# %%
result2_df.groupby('keyword').agg(['mean', 'std']).plot.bar()
# Out:
# <ipython-input-93-05f719dc2430>:1: FutureWarning: ['reply', 'leetWords', 'BestMatches', 'NewReply'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   result2_df.groupby('keyword').agg(['mean', 'std']).plot.bar()
# <Axes: xlabel='keyword'>
