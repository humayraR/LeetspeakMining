# %% [markdown]
# <a href="https://colab.research.google.com/github/humayraR/LeetspeakMining/blob/main/Youtube_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Accuracy test analysis

# %%
result1_df = pd.read_csv("test1_noLeet_setiment_result.csv")
result1_df
# Out:
#                                                     text       Neg       Neu  \
# 0      Ok I hate to tell everyone but 90s quality is ...  0.171523  0.257676
# 1      Actually the recent windows update made my pc ...  0.014980  0.076991
# 2      Tom I really hope you enjoyed your stay in War...  0.002816  0.012929
# 3      OR, more likely, they hired a professional who...  0.330295  0.606575
# 4               I am confused because of Linus's tshirt.  0.527813  0.462156
# ...                                                  ...       ...       ...
# 57640  I think I remember Rome testing its water with...  0.038654  0.916290
# 57641  "<a href=""https://www.youtube.com/watch?v=G02...  0.019085  0.728379
# 57642  Lasers revert Tom Scott brain back to a 12 yea...  0.070997  0.737095
# 57643  I don't care what religion you follow. If you ...  0.083278  0.581044
# 57644  Headphones --&gt; Bluetooth<br>Data --&gt; WiF...  0.017479  0.891058
#
#             Pos
# 0      0.570801
# 1      0.908029
# 2      0.984255
# 3      0.063130
# 4      0.010031
# ...         ...
# 57640  0.045057
# 57641  0.252536
# 57642  0.191907
# 57643  0.335678
# 57644  0.091463
#
# [57645 rows x 4 columns]

# %%
# prompt: Using dataframe result1_df: suggest a plot

result1_df.hist(['Neg', 'Neu', 'Pos'])
# Out:
# array([[<Axes: title={'center': 'Neg'}>, <Axes: title={'center': 'Neu'}>],
#        [<Axes: title={'center': 'Pos'}>, <Axes: >]], dtype=object)
